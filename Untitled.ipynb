# %%
%clear
# Out:
# SCAD code buffer has been cleared

# %%
cube([2, 2, 2]);
numberOfPis=2;
%display piCaseBottom();
# Out:
# WARNING: Ignoring unknown module 'piCaseBottom', in file tmp_9n12ct7.scad, line 5.
# Compiling design (CSG Products normalization)...
# Normalized CSG tree has 2 elements

# %%
cube([1,1,1]);
# Out:
# Number of lines of OpenSCAD code: 2

# %%
%lsmagic
# Out:
# Available Commands: %clear %display %displayCode %%display %mime %command %lsmagic %include %use %saveAs

# %%
// testDimensions();
# Out:
# Number of lines of OpenSCAD code: 166
